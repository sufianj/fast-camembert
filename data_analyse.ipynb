# %%
import seaborn as sns
import pandas as pd

# %%
df_texts = pd.read_csv('./data/raw_data.csv')
all_texts = df_texts['caption'].to_list()
#check average tokenized sentence lenth
lenlist = [len(e.split(' ')) for e in all_texts]
print("average length = ", sum(lenlist) / len(lenlist))
print("maximun length = ", max(lenlist))
# Out:
# average length =  30.90843806104129
# maximun length =  1258

# %%
#check length distribution
sns.displot(lenlist)

# %%
df_labeled_data = pd.read_csv('./data/labeled_data.csv')

# %%
df_labeled_data.describe()
# Out:
#                 id  cadre/atmosphère  probleme technique  temps d'attente  \
# count   323.000000        323.000000          323.000000       323.000000
# mean   1471.380805          0.216718            0.216718         0.275542
# std     747.422229          0.412648            0.412648         0.447480
# min      13.000000          0.000000            0.000000         0.000000
# 25%     824.000000          0.000000            0.000000         0.000000
# 50%    1546.000000          0.000000            0.000000         0.000000
# 75%    2096.500000          0.000000            0.000000         1.000000
# max    2639.000000          1.000000            1.000000         1.000000
#
#        accueil/relation commerciale
# count                    323.000000
# mean                       0.693498
# std                        0.461756
# min                        0.000000
# 25%                        0.000000
# 50%                        1.000000
# 75%                        1.000000
# max                        1.000000

# %%
# check unique label conbinations
df_labeled_data.iloc[1:,2:].drop_duplicates()
# Out:
#      cadre/atmosphère  probleme technique  temps d'attente  \
# 1                   0                   0                1
# 2                   0                   0                0
# 15                  0                   1                1
# 42                  0                   1                0
# 43                  1                   0                0
# 46                  1                   0                1
# 62                  1                   0                0
# 64                  1                   0                1
# 120                 0                   1                0
# 126                 1                   1                0
# 131                 0                   1                1
# 137                 0                   0                0
# 170                 1                   1                0
# 235                 0                   0                1
#
#      accueil/relation commerciale
# 1                               1
# 2                               1
# 15                              1
# 42                              1
# 43                              1
# 46                              1
# 62                              0
# 64                              0
# 120                             0
# 126                             0
# 131                             0
# 137                             0
# 170                             1
# 235                             0

# %%
df_labeled_data.groupby(['cadre/atmosphère','probleme technique', "temps d'attente", 'accueil/relation commerciale']).count()
# Out:
#                                                                                    id  \
# cadre/atmosphère probleme technique temps d'attente accueil/relation commerciale
# 0                0                  0               0                               2
#                                                     1                             114
#                                     1               0                              31
#                                                     1                              38
#                  1                  0               0                              23
#                                                     1                              38
#                                     1               0                               3
#                                                     1                               4
# 1                0                  0               0                              34
#                                                     1                              21
#                                     1               0                               5
#                                                     1                               8
#                  1                  0               0                               1
#                                                     1                               1
#
#                                                                                   review
# cadre/atmosphère probleme technique temps d'attente accueil/relation commerciale
# 0                0                  0               0                                  2
#                                                     1                                114
#                                     1               0                                 31
#                                                     1                                 38
#                  1                  0               0                                 23
#                                                     1                                 38
#                                     1               0                                  3
#                                                     1                                  4
# 1                0                  0               0                                 34
#                                                     1                                 21
#                                     1               0                                  5
#                                                     1                                  8
#                  1                  0               0                                  1
#                                                     1                                  1

# %%
df_labeled_data.loc[(df_labeled_data['cadre/atmosphère'] == 0) &
                   (df_labeled_data['probleme technique'] == 0) &
                   (df_labeled_data["temps d'attente"] == 0) &
                   (df_labeled_data['accueil/relation commerciale'] == 0)]
# Out:
#       id                                             review  cadre/atmosphère  \
# 137  799  ma demande (un changement de box consécutif à ...                 0
# 308  655                           des choses intéressantes                 0
#
#      probleme technique  temps d'attente  accueil/relation commerciale
# 137                   0                0                             0
# 308                   0                0                             0
